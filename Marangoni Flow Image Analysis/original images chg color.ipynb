# %%
import imgaug.augmenters as iaa;
import cv2;
import os;
import random;
import glob;
#---------------------------------------------------------------------------------------------------------
# 파일 로딩
path = 'C:/Users/Han/Desktop/auto_selling/dataset1_ex/*.jpg'
#--------------------------------------------------------------------------------------------------------
#%% 색깔 바꾸기(Gamma contrast, 감마보정)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.GammaContrast((0.5, 2.0), per_channel=True);
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'gamma_contrast_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'gamma_contrast_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 색깔 바꾸기(log contrast)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.LogContrast(gain=(0.6, 1.4), per_channel=True);
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'log_contrast_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'log_contrast_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 색깔 바꾸기 (color temperature)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.ChangeColorTemperature((1100, 10000));
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'color_temp_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'color_temp_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 반대 픽셀(inverse pixel)
n = 5; # 만들 사진의 갯수
titles = random.sample(glob.glob(path), n);
for img in range(n):
    title = titles[img];
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.Invert(1.0);
    image_aug = aug(image = image);    
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'invert_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'invert_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 블러(Gaussian blur)
n = 5; # 만들 사진의 갯수
titles = random.sample(glob.glob(path), n);
for img in range(n):
    title = titles[img];
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.GaussianBlur(sigma=(0.8, 3.0));
    image_aug = aug(image = image);    
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'gaussian_blur_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'gaussian_blur_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 블러(avg blur)
n = 5; # 만들 사진의 갯수
titles = random.sample(glob.glob(path), n);
for img in range(n):
    title = titles[img];
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.AverageBlur(k=(2, 11));
    image_aug = aug(image = image);    
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'avg_blur_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'avg_blur_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 노이즈 만들기(가우시언 노이즈)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.imgcorruptlike.GaussianNoise(severity=(2, 4));
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'gaussian_noise_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'gaussian_noise_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 노이즈 만들기(pepper)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = aug = iaa.Pepper(0.1);
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'pepper_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'pepper_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 노이즈 만들기(salt)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.Salt(0.1);
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'salt_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'salt_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 밝기 조정(brightness)
n = 5; # 만들 사진의 갯수
titles = random.sample(glob.glob(path), n);
for img in range(n):
    title = titles[img];
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.imgcorruptlike.Brightness(severity=(3,5));
    image_aug = aug(image = image);    
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'brightness_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'brightness_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 그림 가리기(coarse dropout-10%)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.CoarseDropout(0.1, size_percent=0.1, per_channel=0.5);
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'coarse_dropout_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'coarse_dropout_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 그림 가리기(coarse pepper-10%)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.CoarsePepper(0.1, size_percent=(0.01, 0.1));
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'coarse_pepper_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'coarse_pepper_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 그림 가리기(coarse salt-10%)
n = 5; # 만들 사진의 갯수
for img in range(n):
    title = random.choice(glob.glob(path));
    image = cv2.imread(title);
    lines = open(str(title[:-4]+ '.txt'), 'r');
    aug = iaa.CoarseSalt(0.1, size_percent=(0.01, 0.1));
    image_aug = aug(image = image);
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'coarse_salt_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'coarse_salt_'+str(img) +'.txt', 'w');
    txt.write(lines.read());
    lines.close();
    txt.close();
#%% 그림 회전(위아래)
n = 5; # 만들 사진의 갯수
titles = random.sample(glob.glob(path), n);
for img in range(n):
    title = titles[img];
    image = cv2.imread(title);
    texts = [];
    lines = open(str(title[:-4]+ '.txt'), 'r').readlines();
    for line in range(len(lines)):
        lines[line] = lines[line][:-1].split(' ');
    texts.append(lines);
    aug = iaa.Flipud(1.0);
    bbs_aug = [];
    for line in range(len(lines)):
        bbs_aug.append([texts[0][line][0]+' ' ,texts[0][line][1]+' ',str(1.0-float(texts[0][line][2]))+' ',texts[0][line][3]+' ',texts[0][line][4]+'\n']);
    image_aug = aug(image = image);    
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'flipud_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'flipud_'+str(img) +'.txt', 'w');
    for j in range(len(lines)):
        txt.writelines([bbs_aug[j][0], bbs_aug[j][1], bbs_aug[j][2], bbs_aug[j][3], bbs_aug[j][4]]);
    txt.close();
#%% 그림 회전(좌우)
n = 5; # 만들 사진의 갯수
titles = random.sample(glob.glob(path), n);
for img in range(n):
    title = titles[img];
    image = cv2.imread(title);
    texts = [];
    lines = open(str(title[:-4]+ '.txt'), 'r').readlines();
    for line in range(len(lines)):
        lines[line] = lines[line][:-1].split(' ');
    texts.append(lines);
    aug = iaa.Fliplr(1.0);
    bbs_aug = [];
    for line in range(len(lines)):
        bbs_aug.append([texts[0][line][0]+' ' ,str(1.0-float(texts[0][line][1]))+' ',texts[0][line][2]+' ',texts[0][line][3]+' ',texts[0][line][4]+'\n']);
    image_aug = aug(image = image);    
    cv2.imwrite(os.path.join('C:/Users/Han/Desktop/auto_selling/Aug/', f'fliplr_'+str(img)+'.jpg'), image_aug);
    txt = open('C:/Users/Han/Desktop/auto_selling/Aug/'+'fliplr_'+str(img) +'.txt', 'w');
    for j in range(len(lines)):
        txt.writelines([bbs_aug[j][0], bbs_aug[j][1], bbs_aug[j][2], bbs_aug[j][3], bbs_aug[j][4]]);
    txt.close();

# %%
## Original Images Changing Colors After Cropping

import os

# All files' names in this directory
path = '/content/drive/MyDrive/cbe_paper/rod_particle_marangoni_cropped/'
os.chdir(path)
files = os.listdir(path)
print(files)
# Out:
# ['Rod particle_marangoni_00_00_00_02_6.jpg', 'Rod particle_marangoni_00_00_00_01_5.jpg', 'Rod particle_marangoni_00_00_00_01_3.jpg', 'Rod particle_marangoni_00_00_00_00_1.jpg', 'Rod particle_marangoni_00_00_00_01_4.jpg', 'Rod particle_marangoni_00_00_00_00_0.jpg', 'Rod particle_marangoni_00_00_00_00_2.jpg', 'Rod particle_marangoni_00_00_00_02_7.jpg', 'Rod particle_marangoni_00_00_00_04_12.jpg', 'Rod particle_marangoni_00_00_00_05_15.jpg', 'Rod particle_marangoni_00_00_00_03_10.jpg', 'Rod particle_marangoni_00_00_00_02_8.jpg', 'Rod particle_marangoni_00_00_00_03_11.jpg', 'Rod particle_marangoni_00_00_00_05_14.jpg', 'Rod particle_marangoni_00_00_00_03_9.jpg', 'Rod particle_marangoni_00_00_00_04_13.jpg', 'Rod particle_marangoni_00_00_00_05_17.jpg', 'Rod particle_marangoni_00_00_00_07_22.jpg', 'Rod particle_marangoni_00_00_00_05_16.jpg', 'Rod particle_marangoni_00_00_00_07_21.jpg', 'Rod particle_marangoni_00_00_00_06_20.jpg', 'Rod particle_marangoni_00_00_00_06_19.jpg', 'Rod particle_marangoni_00_00_00_06_18.jpg', 'Rod particle_marangoni_00_00_00_09_27.jpg', 'Rod particle_marangoni_00_00_00_08_26.jpg', 'Rod particle_marangoni_00_00_00_08_25.jpg', 'Rod particle_marangoni_00_00_00_08_24.jpg', 'Rod particle_marangoni_00_00_00_07_23.jpg', 'Rod particle_marangoni_00_00_00_09_28.jpg', 'Rod particle_marangoni_00_00_01_00_32.jpg', 'Rod particle_marangoni_00_00_00_09_29.jpg', 'Rod particle_marangoni_00_00_01_00_30.jpg', 'Rod particle_marangoni_00_00_01_00_31.jpg', 'Rod particle_marangoni_00_00_01_01_34.
  cv2.imwrite(os.path.join(new_path + files[image]), img_aug)

# %%
import imgaug.augmenters as iaa;
import cv2;
import os;
import random;
import glob;
from imagecorruptions import corrupt

#---------------------------------------------------------------------------------------------------------
# 파일 로딩
title = '/content/drive/MyDrive/cbe_paper/rod_particle_marangoni_cropped/Rod particle_marangoni_00_00_00_01_5.jpg'
#--------------------------------------------------------------------------------------------------------
#%% 색깔 바꾸기(Gamma contrast, 감마보정)
image = cv2.imread(title);
aug = iaa.GammaContrast((0.5, 2.0), per_channel=True);
image_aug = aug(image = image);
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/gamma_contrast.jpg'), image_aug);

#%% 색깔 바꾸기(log contrast)
image = cv2.imread(title);
aug = iaa.LogContrast(gain=(0.6, 1.4), per_channel=True);
image_aug = aug(image = image);
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/log_contrast.jpg'), image_aug);

#%% 색깔 바꾸기 (color temperature)
#image = cv2.imread(title);
##aug = iaa.ChangeColorTemperature((1100, 10000));
#image_aug = aug(image = image);
#cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/color_temp.jpg'), image_aug);

#%% 반대 픽셀(inverse pixel)
image = cv2.imread(title);
aug = iaa.Invert(1.0);
image_aug = aug(image = image);    
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/invert.jpg'), image_aug);

#%% 블러(Gaussian blur)
image = cv2.imread(title);
aug = iaa.GaussianBlur(sigma=(0.8, 3.0));
image_aug = aug(image = image);    
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/gaussian_blur.jpg'), image_aug);

#%% 블러(avg blur)
image = cv2.imread(title);
aug = iaa.AverageBlur(k=(2, 11));
image_aug = aug(image = image);    
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/avg_blur.jpg'), image_aug);

#%% 노이즈 만들기(가우시언 노이즈)
#image = cv2.imread(title);
#aug = iaa.imgcorruptlike.GaussianNoise(severity=(2, 4));
#image_aug = aug(image = image);
#cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/gaussian_noise.jpg'), image_aug);

#%% 노이즈 만들기(pepper)
image = cv2.imread(title);
aug = iaa.Pepper(0.1);
image_aug = aug(image = image);
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/pepper.jpg'), image_aug);

#%% 노이즈 만들기(salt)
image = cv2.imread(title);
aug = iaa.Salt(0.1);
image_aug = aug(image = image);
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/salt.jpg'), image_aug);

#%% 밝기 조정(brightness)
#image = cv2.imread(title);
#aug = iaa.imgcorruptlike.Brightness(severity=(3,5));
#image_aug = aug(image = image);    
#cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/brightness.jpg'), image_aug);

#%% 그림 가리기(coarse dropout-10%)
image = cv2.imread(title);
aug = iaa.CoarseDropout(0.1, size_percent=0.1, per_channel=0.5);
image_aug = aug(image = image);
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/coarse_dropout.jpg'), image_aug);

#%% 그림 가리기(coarse pepper-10%)
image = cv2.imread(title);
aug = iaa.CoarsePepper(0.1, size_percent=(0.01, 0.1));
image_aug = aug(image = image);
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/coarse_pepper.jpg'), image_aug);

#%% 그림 가리기(coarse salt-10%)
image = cv2.imread(title);
aug = iaa.CoarseSalt(0.1, size_percent=(0.01, 0.1));
image_aug = aug(image = image);
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/coarse_salt.jpg'), image_aug);

#%% 그림 회전(위아래)
image = cv2.imread(title);
aug = iaa.Flipud(1.0);
image_aug = aug(image = image);    
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/flipud.jpg'), image_aug);

#%% 그림 회전(좌우)
image = cv2.imread(title);
aug = iaa.Fliplr(1.0);
image_aug = aug(image = image);    
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/fliplr.jpg'), image_aug);

#%% 밝기 조정(다른 라이브러리)
image = cv2.imread(title);
img_aug =  corrupt(image, corruption_name = 'brightness', severity = 2)
cv2.imwrite(os.path.join('/content/drive/MyDrive/cbe_paper/data_aug_practice/brightness.jpg'), img_aug)
# Out:
# True
